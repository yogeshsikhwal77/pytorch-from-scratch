# %%
import torch

# %%
x = torch.tensor([[1,2,3],[3,4,5]])
x
# Out:
# tensor([[1, 2, 3],
#         [3, 4, 5]])

# %%
x.dtype
# Out:
# torch.int64

# %%
torch.tensor([2.0,3.5,9.0],dtype=torch.int32)
# Out:
# tensor([2, 2, 9], dtype=torch.int32)

# %%
torch.tensor([1,2,3],dtype=torch.float64)
# Out:
# tensor([1., 2., 3.], dtype=torch.float64)

# %%
x.to(torch.float64)
# Out:
# tensor([[1., 2., 3.],
#         [3., 4., 5.]], dtype=torch.float64)

# %%
torch.rand_like(x,dtype=torch.float64)
# Out:
# tensor([[0.6911, 0.3713, 0.1935],
#         [0.7557, 0.5887, 0.4513]], dtype=torch.float64)
