# %%
import torch
print(torch.__version__)
# Out:
# 2.5.1+cu121

# %%
if torch.cuda.is_available():
    print({torch.cuda.get_device_name()})
else:
    print("not found")
# Out:
# {'NVIDIA GeForce RTX 4050 Laptop GPU'}

# %% [markdown]
# ## Creating a Tensor

# %%
a = torch.empty(2,3)
print(a)
# Out:
# tensor([[-9.6969e-27,  1.4910e-42,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00]])

# %%
type(a)
# Out:
# torch.Tensor

# %%
torch.zeros(2,3)
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])

# %%
torch.ones(2,3)
# Out:
# tensor([[1., 1., 1.],
#         [1., 1., 1.]])

# %%
torch.rand(2,3)  # 0 -> 1 random values
# Out:
# tensor([[0.8417, 0.6083, 0.5598],
#         [0.0437, 0.0357, 0.4354]])

# %%
torch.rand(2,3)   # different
# Out:
# tensor([[0.2862, 0.8282, 0.6217],
#         [0.3448, 0.3771, 0.5715]])

# %%
torch.manual_seed(100)
torch.rand(2,3)
# Out:
# tensor([[0.1117, 0.8158, 0.2626],
#         [0.4839, 0.6765, 0.7539]])

# %%
torch.manual_seed(100)
torch.rand(2,3)  # same upper and loser random value
# Out:
# tensor([[0.1117, 0.8158, 0.2626],
#         [0.4839, 0.6765, 0.7539]])

# %%
torch.tensor([[1,2,3],[4,5,6]])
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
torch.arange(0,25,4)
# Out:
# tensor([ 0,  4,  8, 12, 16, 20, 24])

# %%
torch.linspace(0,15,7)
# Out:
# tensor([ 0.0000,  2.5000,  5.0000,  7.5000, 10.0000, 12.5000, 15.0000])

# %%
torch.eye(2)
# Out:
# tensor([[1., 0.],
#         [0., 1.]])

# %%
torch.full((2,3),7)
# Out:
# tensor([[7, 7, 7],
#         [7, 7, 7]])
