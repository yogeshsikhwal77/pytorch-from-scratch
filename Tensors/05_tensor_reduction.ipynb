# %%
import torch

# %%
e = torch.randint(size=(2,3),low=0,high=10,dtype=torch.float64)
e
# Out:
# tensor([[7., 3., 1.],
#         [9., 6., 0.]], dtype=torch.float64)

# %%
torch.sum(e)
# Out:
# tensor(26., dtype=torch.float64)

# %%
torch.sum(e,axis=1)
torch.sum(e,axis=0)
# Out:
# tensor([16.,  9.,  1.], dtype=torch.float64)

# %%
torch.mean(e)
# Out:
# tensor(4.3333, dtype=torch.float64)

# %%
torch.median(e)
# Out:
# tensor(3., dtype=torch.float64)

# %%
torch.max(e)
torch.min(e)
# Out:
# tensor(0., dtype=torch.float64)

# %%
torch.prod(e) # product of all elements
# Out:
# tensor(0., dtype=torch.float64)

# %%
torch.std(e)
# Out:
# tensor(3.5590, dtype=torch.float64)

# %%
torch.var(e)
# Out:
# tensor(12.6667, dtype=torch.float64)

# %%
torch.argmax(e)
torch.argmin(e)
# Out:
# tensor(5)
